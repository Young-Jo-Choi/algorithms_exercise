# %% [markdown]
# # 수 정렬하기
# ## 문제
# N개의 수가 주어졌을 때, 이를 오름차순으로 정렬하는 프로그램을 작성하시오.
#
# ## 입력
# 첫째 줄에 수의 개수 N(1 ≤ N ≤ 1,000)이 주어진다. 둘째 줄부터 N개의 줄에는 수 주어진다. 이 수는 절댓값이 1,000보다 작거나 같은 정수이다. 수는 중복되지 않는다.
#
# ## 출력
# 첫째 줄부터 N개의 줄에 오름차순으로 정렬한 결과를 한 줄에 하나씩 출력한다.

# %%
# 거품정렬 사용 (O(log(n^2)))
# sort 함수는 너무 간단하므로 지양
N = int(input())
numbers = []
for i in range(N):
    numbers.append(int(input()))

no_change = True
cnt = 1
while cnt>0:
    cnt = 0
    for n in  range(0,len(numbers)-1):
        if numbers[n] > numbers[n+1]:
            big_number = numbers[n]
            small_number = numbers[n+1]
            numbers[n] = small_number
            numbers[n+1] = big_number
            cnt += 1

for n in numbers:
    print(n)
# Out:
# 5
# 5
# 3
# 2
# 4
# 1
# 1
# 2
# 3
# 4
# 5

# %%
# 런타임 에러 -> 6.14에 재시도
# 퀵정렬 사용 (O(n log n))
# def quick_sort(x:list) -> list:
#     if len(x) == 2:
#         if x[0] > x[1]:
#             return list(x[1],x[0])
#     elif len(x) == 1:
#         return x
#     else:
#         return 



def qsort_1step(numbers):
    if type(numbers)==int:
        numbers = [numbers]
    if len(numbers)<=1:
        return numbers
    standard = numbers[len(numbers)//2]
    front = []
    back = []
    for number in numbers:
        if number > standard:
            back.append(number)
        elif number < standard:
            front.append(number)
    return qsort_1step(front)+[standard]+qsort_1step(back)

N = int(input())
nums = []
for i in range(N):
    nums.append(int(sys.stdin.readline()))
sorted = qsort_1step(nums)
for i in sorted:
    print(i)
# Out:
# 5
# 5
# 4
# 3
# 2
# 1
# 1
# 2
# 3
# 4
# 5

# %%
def qsort_1step(numbers):
    if len(numbers)<=1:
        return numbers
    standard = numbers[len(numbers)//2]
    front = []
    back = []
    for number in numbers:
        if number > standard:
            back.append(number)
        elif number < standard:
            front.append(number)
    return qsort_1step(front)+[standard]+qsort_1step(back)
import numpy as np
aa = list(np.unique(np.random.randint(1,1000,size=100)))

# %%
import sys
n = int(input())
nums = []
for i in range(n):
    nums.append(int(sys.stdin.readline()))
    
def qsort_1step(numbers):
    if len(numbers)<=1:
        return numbers
    else:
        standard = numbers[len(numbers)//2]
        front = []
        back = []
        for number in numbers:
            if number > standard:
                back.append(number)
            elif number < standard:
                front.append(number)
        return qsort_1step(front)+[standard]+qsort_1step(back)

sorted_list = qsort_1step(nums)
for i in sorted_list:
    print(i)
# Out:
# 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-59f6ce5344be> in <module>()
#       3 nums = []
#       4 for i in range(n):
# ----> 5     nums.append(int(sys.stdin.readline()))
#       6
#       7 def qsort_1step(numbers):
#
# ValueError: invalid literal for int() with base 10: ''
